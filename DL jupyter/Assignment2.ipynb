# %%
# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Flatten, MaxPooling2D, Dropout
from sklearn.metrics import classification_report

# %% [markdown]
# ### Load Dataset

# %%
train_df = pd.read_csv('fashion-mnist_train.csv')
test_df = pd.read_csv('fashion-mnist_test.csv')

# %%
train_df.shape
# Out:
# (60000, 785)

# %%
test_df.shape
# Out:
# (10000, 785)

# %% [markdown]
# ### Preprocess Data
# Convert each image of 784 into (28x28x1)(height x width x color_channels). Divide values by 255 to scale the values.

# %%
# Get the labels (target variable) and pixel values (features)
x_train = train_df.iloc[:, 1:].to_numpy()
y_train = train_df.iloc[:, 0].to_numpy()
x_test = test_df.iloc[:, 1:].to_numpy()
y_test = test_df.iloc[:, 0].to_numpy()

# %%
# Reshape the images from 784 pixels (28x28) into 28x28x1 (grayscale)
x_train = x_train.reshape([-1, 28, 28, 1])
x_test = x_test.reshape([-1, 28, 28, 1])

# %%
# Normalize pixel values to be between 0 and 1
x_train = x_train / 255.0
x_test = x_test / 255.0

# %%
# Class names corresponding to the labels (0-9)
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# ### Visualization

# %%
# Plot the first 25 images from the training set
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %% [markdown]
# ### Model Building

# %%
model = Sequential()

# %%
# Convolutional Layer + MaxPooling + Dropout
model.add(Conv2D(filters=64, kernel_size=(3, 3), input_shape=(28, 28, 1), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(rate=0.3))
# Out:
# C:\Users\91776\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Flatten and Fully Connected Layers
model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=10, activation='softmax'))  # Softmax for multi-class classification

# %%
# Compile the model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Display the model summary
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 26, 26, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 10816)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 32)                  │         346,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 347,114 (1.32 MB)
#  Trainable params: 347,114 (1.32 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # TRAINING THE MODEL

# %%
# Train the model with 50 epochs and a batch size of 1200
history = model.fit(x_train, y_train, epochs=50, batch_size=1200, validation_split=0.05)
# Out:
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 9s 170ms/step - accuracy: 0.5116 - loss: 1.4131 - val_accuracy: 0.8013 - val_loss: 0.5591
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.8229 - loss: 0.5057 - val_accuracy: 0.8283 - val_loss: 0.4707
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 165ms/step - accuracy: 0.8524 - loss: 0.4249 - val_accuracy: 0.8560 - val_loss: 0.4093
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 163ms/step - accuracy: 0.8649 - loss: 0.3873 - val_accuracy: 0.8633 - val_loss: 0.3805
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 165ms/step - accuracy: 0.8723 - loss: 0.3659 - val_accuracy: 0.8720 - val_loss: 0.3614
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 171ms/step - accuracy: 0.8806 - loss: 0.3429 - val_accuracy: 0.8783 - val_loss: 0.3470
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 165ms/step - accuracy: 0.8833 - loss: 0.3302 - val_accuracy: 0.8860 - val_loss: 0.3296
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 170ms/step - accuracy: 0.8917 - loss: 0.3127 - val_accuracy: 0.8870 - val_loss: 0.3223
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 172ms/step - accuracy: 0.8942 - loss: 0.3061 - val_accuracy: 0.8867 - val_loss: 0.3207
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 164ms/step - accuracy: 0.8965 - loss: 0.2943 - val_accuracy: 0.8937 - val_loss: 0.3130
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.8960 - loss: 0.2923 - val_accuracy: 0.8900 - val_loss: 0.3145
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 163ms/step - accuracy: 0.8976 - loss: 0.2884 - val_accuracy: 0.8927 - val_loss: 0.3071
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.9006 - loss: 0.2830 - val_accuracy: 0.8940 - val_loss: 0.2990
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 147ms/step - accuracy: 0.9060 - loss: 0.2695 - val_accuracy: 0.8977 - val_loss: 0.2905
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.9044 - loss: 0.2694 - val_accuracy: 0.9013 - val_loss: 0.2877
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.9050 - loss: 0.2686 - val_accuracy: 0.9000 - val_loss: 0.2871
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 146ms/step - accuracy: 0.9067 - loss: 0.2582 - val_accuracy: 0.8993 - val_loss: 0.2884
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 151ms/step - accuracy: 0.9102 - loss: 0.2529 - val_accuracy: 0.9030 - val_loss: 0.2810
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - accuracy: 0.9103 - loss: 0.2491 - val_accuracy: 0.9033 - val_loss: 0.2824
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.9119 - loss: 0.2452 - val_accuracy: 0.8997 - val_loss: 0.2806
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 151ms/step - accuracy: 0.9136 - loss: 0.2418 - val_accuracy: 0.9047 - val_loss: 0.2751
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - accuracy: 0.9144 - loss: 0.2397 - val_accuracy: 0.9060 - val_loss: 0.2728
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 152ms/step - accuracy: 0.9158 - loss: 0.2363 - val_accuracy: 0.8997 - val_loss: 0.2824
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - accuracy: 0.9150 - loss: 0.2391 - val_accuracy: 0.9077 - val_loss: 0.2696
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.9191 - loss: 0.2288 - val_accuracy: 0.9113 - val_loss: 0.2696
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.9189 - loss: 0.2245 - val_accuracy: 0.9090 - val_loss: 0.2664
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 159ms/step - accuracy: 0.9222 - loss: 0.2170 - val_accuracy: 0.9103 - val_loss: 0.2650
# Epoch 28/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 156ms/step - accuracy: 0.9212 - loss: 0.2183 - val_accuracy: 0.9053 - val_loss: 0.2719
# Epoch 29/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 157ms/step - accuracy: 0.9240 - loss: 0.2126 - val_accuracy: 0.9110 - val_loss: 0.2701
# Epoch 30/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 153ms/step - accuracy: 0.9228 - loss: 0.2093 - val_accuracy: 0.9113 - val_loss: 0.2628
# Epoch 31/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.9241 - loss: 0.2109 - val_accuracy: 0.9123 - val_loss: 0.2620
# Epoch 32/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.9257 - loss: 0.2041 - val_accuracy: 0.9117 - val_loss: 0.2592
# Epoch 33/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.9252 - loss: 0.2047 - val_accuracy: 0.9103 - val_loss: 0.2607
# Epoch 34/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 151ms/step - accuracy: 0.9232 - loss: 0.2111 - val_accuracy: 0.9107 - val_loss: 0.2615
# Epoch 35/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - accuracy: 0.9272 - loss: 0.2000 - val_accuracy: 0.9143 - val_loss: 0.2565
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - accuracy: 0.9269 - loss: 0.2004 - val_accuracy: 0.9123 - val_loss: 0.2589
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 150ms/step - accuracy: 0.9309 - loss: 0.1972 - val_accuracy: 0.9137 - val_loss: 0.2619
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 151ms/step - accuracy: 0.9306 - loss: 0.1934 - val_accuracy: 0.9133 - val_loss: 0.2551
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 161ms/step - accuracy: 0.9323 - loss: 0.1884 - val_accuracy: 0.9113 - val_loss: 0.2573
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 157ms/step - accuracy: 0.9320 - loss: 0.1890 - val_accuracy: 0.9143 - val_loss: 0.2538
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 156ms/step - accuracy: 0.9329 - loss: 0.1881 - val_accuracy: 0.9160 - val_loss: 0.2575
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 157ms/step - accuracy: 0.9327 - loss: 0.1847 - val_accuracy: 0.9103 - val_loss: 0.2634
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.9344 - loss: 0.1813 - val_accuracy: 0.9170 - val_loss: 0.2574
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 157ms/step - accuracy: 0.9355 - loss: 0.1777 - val_accuracy: 0.9147 - val_loss: 0.2546
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - accuracy: 0.9343 - loss: 0.1785 - val_accuracy: 0.9117 - val_loss: 0.2594
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 158ms/step - accuracy: 0.9366 - loss: 0.1774 - val_accuracy: 0.9137 - val_loss: 0.2632
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 8s 160ms/step - accuracy: 0.9344 - loss: 0.1785 - val_accuracy: 0.9170 - val_loss: 0.2540
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 149ms/step - accuracy: 0.9354 - loss: 0.1784 - val_accuracy: 0.9150 - val_loss: 0.2552
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 151ms/step - accuracy: 0.9372 - loss: 0.1712 - val_accuracy: 0.9180 - val_loss: 0.2489
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 7s 148ms/step - accuracy: 0.9418 - loss: 0.1649 - val_accuracy: 0.9123 - val_loss: 0.2565

# %% [markdown]
# ### Evaluation

# %%
# Evaluate the model on the test set
evaluation = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {evaluation[1]}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9153 - loss: 0.2409
# Test Accuracy: 0.919700026512146

# %% [markdown]
# MAKING PREDICTIONS

# %%
# Get the predicted class labels
y_probas = model.predict(x_test)
y_pred = y_probas.argmax(axis=-1)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %%
# Visualize some of the test images with predicted labels
plt.figure(figsize=(10, 10))
for i in range(25):
    plt.subplot(5, 5, i + 1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.binary)
    plt.title(f"Pred: {class_names[y_pred[i]]}")
plt.show()

# %%
# Print classification report
num_classes = 10
class_names_report = ["class {}".format(i) for i in range(num_classes)]
cr = classification_report(y_test, y_pred, target_names=class_names_report)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.86      0.86      0.86      1000
#      class 1       0.98      0.98      0.98      1000
#      class 2       0.90      0.86      0.88      1000
#      class 3       0.92      0.93      0.93      1000
#      class 4       0.89      0.89      0.89      1000
#      class 5       0.99      0.97      0.98      1000
#      class 6       0.76      0.79      0.78      1000
#      class 7       0.95      0.97      0.96      1000
#      class 8       0.99      0.97      0.98      1000
#      class 9       0.96      0.97      0.97      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
